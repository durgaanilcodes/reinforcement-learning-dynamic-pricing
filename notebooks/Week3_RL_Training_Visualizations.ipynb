# %% [markdown]
# # Week 3 – Reinforcement Learning Training Visualizations
#
# ## Project
# Travel & Hospitality – Reinforcement Learning for Dynamic Pricing
#
# **Prepared By:** Krutika Thakur
#
# ---
#
# ## Objective
#
# The objective of Week 3 is to create visualizations that analyze the performance of the Reinforcement Learning (RL) pricing agent during training.
#
# The graphs in this notebook demonstrate how the agent improves over time by analysing reward trends, pricing decisions, customer demand, and revenue.
#
# > **Note:** The visualizations currently use simulated training data for demonstration purposes. They can be updated with the actual Reinforcement Learning training outputs once available from the training team.

# %% [markdown]
# ## Introduction
#
# Reinforcement Learning enables an agent to learn optimal pricing decisions by interacting with a simulated market environment.
#
# During training, the agent repeatedly selects ticket prices, observes customer responses, receives rewards, and updates its policy to maximise long-term revenue.
#
# The following visualizations illustrate different aspects of the training process.

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

print("Libraries imported successfully!")
# Out:
# Libraries imported successfully!

# %% [markdown]
# ## 1. Reward vs Episode
#
# ## 2. Price vs Demand
#
# ## 3. Revenue Comparison
#
# ## 4. Training Progress
#
# ## 5. Moving Average Reward
#
# ## 6. Policy Improvement
#
# ## Conclusion

# %%
import pandas as pd

df = pd.read_csv("/content/synthetic_booking_data.csv")

df.head()
# Out:
#    Booking_ID    Hotel_Type    Season  Rooms_Available  Base_Price  \
# 0           1    City Hotel  Off-Peak               37         229
# 1           2  Resort Hotel   Holiday               90         192
# 2           3    City Hotel      Peak              123         260
# 3           4    City Hotel      Peak               49         184
# 4           5    City Hotel      Peak               54         292
#
#   Demand_Level  Booking_Probability  Dynamic_Price  Revenue
# 0          Low                 0.60         234.10   140.46
# 1          Low                 0.76         188.46   143.23
# 2         High                 0.63         223.94   141.08
# 3          Low                 0.63         158.78   100.03
# 4          Low                 0.54         273.10   147.47

# %%
import pandas as pd

df = pd.read_csv("/content/synthetic_booking_data.csv")

print("First 5 Rows")
print(df.head())

print("\nColumns")
print(df.columns.tolist())

print("\nInformation")
df.info()
# Out:
# First 5 Rows
#    Booking_ID    Hotel_Type    Season  Rooms_Available  Base_Price  \
# 0           1    City Hotel  Off-Peak               37         229
# 1           2  Resort Hotel   Holiday               90         192
# 2           3    City Hotel      Peak              123         260
# 3           4    City Hotel      Peak               49         184
# 4           5    City Hotel      Peak               54         292
#
#   Demand_Level  Booking_Probability  Dynamic_Price  Revenue
# 0          Low                 0.60         234.10   140.46
# 1          Low                 0.76         188.46   143.23
# 2         High                 0.63         223.94   141.08
# 3          Low                 0.63         158.78   100.03
# 4          Low                 0.54         273.10   147.47
#
# Columns
# ['Booking_ID', 'Hotel_Type', 'Season', 'Rooms_Available', 'Base_Price', 'Demand_Level', 'Booking_Probability', 'Dynamic_Price', 'Revenue']
#
# Information
# ...

# %% [markdown]
# # Reward vs Episode
#
# ## Objective
#
# This visualization shows how the Reinforcement Learning (RL) agent improves during training.
#
# As the number of training episodes increases, the agent learns better pricing strategies, resulting in higher cumulative rewards.
#
# Since the RL model is still under development by the training team, simulated reward values are used for visualization.

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
# Total training episodes

episodes = np.arange(1,101)

# Simulated rewards

np.random.seed(42)

reward = np.linspace(20,250,100) + np.random.normal(0,10,100)

reward = np.maximum(reward,0)

training_df = pd.DataFrame({
    "Episode":episodes,
    "Reward":reward
})

training_df.head()
# Out:
#    Episode     Reward
# 0        1  24.967142
# 1        2  20.940589
# 2        3  31.123350
# 3        4  42.199996
# 4        5  26.951396

# %%
import matplotlib.pyplot as plt

# 1. Create the plot
plt.figure(figsize=(8, 5))
plt.plot(training_df["Episode"], training_df["Reward"], color="b", linewidth=2)

# 2. Add labels and title
plt.title("Reward vs Episode")
plt.xlabel("Episode")
plt.ylabel("Reward")
plt.grid(True)

# 3. Save the figure BEFORE plt.show()
plt.savefig("reward_vs_episode.png", bbox_inches="tight")
plt.show()

# %%
average_reward = training_df["Reward"].mean()

print("Average Reward:",round(average_reward,2))
# Out:
# Average Reward: 133.96

# %% [markdown]
# ## Observation
#
# The graph demonstrates that the reward generally increases as the number of training episodes increases.
#
# Minor fluctuations occur due to the exploration performed by the Reinforcement Learning agent.
#
# Overall, the upward trend indicates that the pricing agent is learning more profitable pricing strategies over time.

# %% [markdown]
# ## Business Interpretation
#
# Increasing rewards indicate improved pricing decisions.
#
# As the Reinforcement Learning agent gains experience, it selects prices that maximize long-term revenue while maintaining customer demand.
#
# This behavior supports revenue optimization in travel and hospitality systems.

# %%
print(df.columns.tolist())
# Out:
# ['Booking_ID', 'Hotel_Type', 'Season', 'Rooms_Available', 'Base_Price', 'Demand_Level', 'Booking_Probability', 'Dynamic_Price', 'Revenue']

# %%
print(df.head())

print("\nColumns:")
print(df.columns.tolist())

print("\nMissing Values:")
print(df.isnull().sum())
# Out:
#    Booking_ID    Hotel_Type    Season  Rooms_Available  Base_Price  \
# 0           1    City Hotel  Off-Peak               37         229
# 1           2  Resort Hotel   Holiday               90         192
# 2           3    City Hotel      Peak              123         260
# 3           4    City Hotel      Peak               49         184
# 4           5    City Hotel      Peak               54         292
#
#   Demand_Level  Booking_Probability  Dynamic_Price  Revenue
# 0          Low                 0.60         234.10   140.46
# 1          Low                 0.76         188.46   143.23
# 2         High                 0.63         223.94   141.08
# 3          Low                 0.63         158.78   100.03
# 4          Low                 0.54         273.10   147.47
#
# Columns:
# ['Booking_ID', 'Hotel_Type', 'Season', 'Rooms_Available', 'Base_Price', 'Demand_Level', 'Booking_Probability', 'Dynamic_Price', 'Revenue']
#
# Missing Values:
# Booking_ID             0
# ...

# %% [markdown]
# # Dynamic Price vs Demand Level
#
# ## Objective
#
# This visualization shows how the dynamically generated price affects customer demand.
#
# The graph helps analyse whether increasing prices decreases customer demand, which is an important concept in Reinforcement Learning based Dynamic Pricing.

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(10,6))

plt.scatter(
    df["Dynamic_Price"],
    df["Demand_Level"],
    alpha=0.7
)

plt.title("Dynamic Price vs Demand Level")

plt.xlabel("Dynamic Price")

plt.ylabel("Demand Level")

plt.grid(True)
plt.savefig("price_vs_demand.png", dpi=300, bbox_inches="tight")
plt.show()

# %% [markdown]
# ## Observation
#
# The graph demonstrates the relationship between dynamic pricing and customer demand.
#
# Generally, higher prices tend to reduce demand, while lower prices attract more bookings.
#
# This relationship helps the Reinforcement Learning agent learn an optimal pricing policy.

# %% [markdown]
# # Revenue Comparison by Hotel Type
#
# ## Objective
#
# Compare the average revenue generated by different hotel types.

# %%
import matplotlib.pyplot as plt

revenue_by_hotel = df.groupby("Hotel_Type")["Revenue"].mean()

plt.figure(figsize=(8,6))

revenue_by_hotel.plot(kind="bar")

plt.title("Average Revenue by Hotel Type")

plt.xlabel("Hotel Type")

plt.ylabel("Average Revenue")

plt.grid(axis="y")
plt.savefig("revenue_comparison.png", dpi=300, bbox_inches="tight")
plt.show()

# %% [markdown]
# ## Observation
#
# The graph compares the average revenue generated by different hotel types.
#
# It helps identify which hotel category contributes more revenue and provides useful insights for pricing strategy.

# %% [markdown]
# # Base Price vs Dynamic Price
#
# ## Objective
#
# Compare the original base price with the dynamically generated price.

# %%
average_prices = [
    df["Base_Price"].mean(),
    df["Dynamic_Price"].mean()
]

labels = [
    "Base Price",
    "Dynamic Price"
]

plt.figure(figsize=(7,5))

plt.bar(labels, average_prices)

plt.title("Average Base Price vs Dynamic Price")

plt.ylabel("Average Price")

for i, value in enumerate(average_prices):
    plt.text(i, value + 2, f"{value:.2f}", ha="center")
plt.savefig("price_comparison.png", dpi=300, bbox_inches="tight")
plt.show()

# %% [markdown]
# # Booking Probability Distribution
#
# ## Objective
#
# Analyse the distribution of booking probabilities in the dataset.

# %%
plt.figure(figsize=(10,6))

plt.hist(df["Booking_Probability"], bins=20)

plt.title("Booking Probability Distribution")

plt.xlabel("Booking Probability")

plt.ylabel("Frequency")

plt.grid(True)
plt.savefig("booking_probability.png", dpi=300, bbox_inches="tight")
plt.show()

# %% [markdown]
# # Training Progress
#
# ## Objective
#
# This visualization represents the learning progress of the Reinforcement Learning agent during training.
#
# The graph illustrates how cumulative rewards improve over multiple training episodes, indicating that the agent is learning better pricing strategies over time.
#
# **Note:** Since the RL model is still being trained by the development team, simulated training values are used for demonstration.

# %%
import numpy as np
import pandas as pd

np.random.seed(42)

episodes = np.arange(1,101)

training_reward = np.linspace(50,300,100)

noise = np.random.normal(0,12,100)

training_reward = training_reward + noise

training_df = pd.DataFrame({
    "Episode":episodes,
    "Reward":training_reward
})

training_df.head()
# Out:
#    Episode     Reward
# 0        1  55.960570
# 1        2  50.866081
# 2        3  62.822768
# 3        4  75.852116
# 4        5  57.291170

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(10,6))

plt.plot(
    training_df["Episode"],
    training_df["Reward"],
    linewidth=2
)

plt.title("Training Progress")

plt.xlabel("Episode")

plt.ylabel("Reward")

plt.grid(True)

plt.savefig(
    "training_progress.png",
    dpi=300,
    bbox_inches="tight"
)

plt.show()

# %%
training_df["Moving_Average"] = training_df["Reward"].rolling(
    window=10
).mean()

plt.figure(figsize=(10,6))

plt.plot(
    training_df["Episode"],
    training_df["Moving_Average"],
    linewidth=3
)

plt.title("Moving Average Reward")

plt.xlabel("Episode")

plt.ylabel("Average Reward")

plt.grid(True)

plt.savefig(
    "moving_average_reward.png",
    dpi=300,
    bbox_inches="tight"
)

plt.show()

# %%
policy_score = np.linspace(40,98,100)

plt.figure(figsize=(10,6))

plt.plot(
    episodes,
    policy_score,
    linewidth=3
)

plt.title("Policy Improvement")

plt.xlabel("Episode")

plt.ylabel("Policy Score (%)")

plt.grid(True)

plt.savefig(
    "policy_improvement.png",
    dpi=300,
    bbox_inches="tight"
)

plt.show()

# %%
print("Average Reward")

print(training_df["Reward"].mean())
# Out:
# Average Reward
# 173.75384179127087

# %% [markdown]
# # Conclusion
#
# The Week 3 visualizations demonstrate the expected learning behaviour of the Reinforcement Learning pricing agent.
#
# The increasing reward trend indicates that the agent improves its pricing decisions over time.
#
# Dataset-based visualizations such as Dynamic Price vs Demand Level, Revenue Comparison, Booking Probability Distribution, and Base Price vs Dynamic Price provide business insights, while the training visualizations represent the learning process of the RL model.
#
# These visualizations will be updated with actual RL training results after the training phase is completed.
